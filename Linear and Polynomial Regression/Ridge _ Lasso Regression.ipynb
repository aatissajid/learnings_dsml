# %% [markdown]
# # Ridge Regression

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import sklearn.preprocessing 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# **Task 1: Import the 'Boston.csv' data file**

# %%
#write code here
data=pd.read_csv('Boston.csv')

# %% [markdown]
# **Task 2: Make a copy of data in 'df'**

# %%
df1 = data
df1.head()
# Out:
#    Crime Rate  Residential Proportion  non-retail business acres/Town  \
# 0     0.00632                    18.0                            2.31
# 1     0.02731                     0.0                            7.07
# 2     0.02729                     0.0                            7.07
# 3     0.03237                     0.0                            2.18
# 4     0.06905                     0.0                            2.18
#
#    Charles River  NO2 concentration  Average Rooms/Dwelling.  \
# 0            0.0              0.538                    6.575
# 1            0.0              0.469                    6.421
# 2            0.0              0.469                    7.185
# 3            0.0              0.458                    6.998
# 4            0.0              0.458                    7.147
#
#    Prior Built Units Proportion  Distance to Employment Centres  \
# 0                          65.2                          4.0900
# 1                          78.9                          4.9671
# 2                          61.1                          4.9671
# 3                          45.8                          6.0622
# 4                          54.2                          6.0622
#
#    Radial Highways Distance  ValueProperty/tax rate  Teacher/town  \
# 0                       1.0                   296.0          15.3
# 1                       2.0                   242.0          17.8
# 2                       2.0                   242.0          17.8
# 3                       3.0                   222.0          18.7
# 4                       3.0                   222.0          18.7
#
#    blacks/town  Lower Status Percent  median home price
# 0       396.90                  4.98               24.0
# 1       396.90                  9.14               21.6
# 2       392.83                  4.03               34.7
# 3       394.63                  2.94               33.4
# 4       396.90                  5.33               36.2

# %%
id(data), id(df1), id(df)
# Out:
# (2485379537864, 2485379537864, 2485379550472)

# %%
#write code here
df=data.copy()

# %%
df.head()
# Out:
#    Crime Rate  Residential Proportion  non-retail business acres/Town  \
# 0     0.00632                    18.0                            2.31
# 1     0.02731                     0.0                            7.07
# 2     0.02729                     0.0                            7.07
# 3     0.03237                     0.0                            2.18
# 4     0.06905                     0.0                            2.18
#
#    Charles River  NO2 concentration  Average Rooms/Dwelling.  \
# 0            0.0              0.538                    6.575
# 1            0.0              0.469                    6.421
# 2            0.0              0.469                    7.185
# 3            0.0              0.458                    6.998
# 4            0.0              0.458                    7.147
#
#    Prior Built Units Proportion  Distance to Employment Centres  \
# 0                          65.2                          4.0900
# 1                          78.9                          4.9671
# 2                          61.1                          4.9671
# 3                          45.8                          6.0622
# 4                          54.2                          6.0622
#
#    Radial Highways Distance  ValueProperty/tax rate  Teacher/town  \
# 0                       1.0                   296.0          15.3
# 1                       2.0                   242.0          17.8
# 2                       2.0                   242.0          17.8
# 3                       3.0                   222.0          18.7
# 4                       3.0                   222.0          18.7
#
#    blacks/town  Lower Status Percent  median home price
# 0       396.90                  4.98               24.0
# 1       396.90                  9.14               21.6
# 2       392.83                  4.03               34.7
# 3       394.63                  2.94               33.4
# 4       396.90                  5.33               36.2

# %% [markdown]
# **Task 3: Display top 5 rows of data**

# %%
#write code here
df.head()
# Out:
#    Crime Rate  Residential Proportion  non-retail business acres/Town  \
# 0     0.00632                    18.0                            2.31
# 1     0.02731                     0.0                            7.07
# 2     0.02729                     0.0                            7.07
# 3     0.03237                     0.0                            2.18
# 4     0.06905                     0.0                            2.18
#
#    Charles River  NO2 concentration  Average Rooms/Dwelling.  \
# 0            0.0              0.538                    6.575
# 1            0.0              0.469                    6.421
# 2            0.0              0.469                    7.185
# 3            0.0              0.458                    6.998
# 4            0.0              0.458                    7.147
#
#    Prior Built Units Proportion  Distance to Employment Centres  \
# 0                          65.2                          4.0900
# 1                          78.9                          4.9671
# 2                          61.1                          4.9671
# 3                          45.8                          6.0622
# 4                          54.2                          6.0622
#
#    Radial Highways Distance  ValueProperty/tax rate  Teacher/town  \
# 0                       1.0                   296.0          15.3
# 1                       2.0                   242.0          17.8
# 2                       2.0                   242.0          17.8
# 3                       3.0                   222.0          18.7
# 4                       3.0                   222.0          18.7
#
#    blacks/town  Lower Status Percent  median home price
# 0       396.90                  4.98               24.0
# 1       396.90                  9.14               21.6
# 2       392.83                  4.03               34.7
# 3       394.63                  2.94               33.4
# 4       396.90                  5.33               36.2

# %% [markdown]
# ### Creating Independent and Dependent Variables

# %% [markdown]
# **Task 4: Create Independent and Dependent variables in 'X' and 'Y' and print their respective shapes.**

# %%
#Write code here
X = df.drop(['median home price'], axis= 1)
Y = df[['median home price']]

# %% [markdown]
# ### Normalization

# %% [markdown]
# **Task 5: Normalize the data by applying MinMax Scaling on X.**

# %%
# scale the features
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
x_scaled_minmax = min_max_scaler.fit_transform(X)
X = pd.DataFrame(x_scaled_minmax, columns = X.columns)
X.head()
# Out:
#    Crime Rate  Residential Proportion  non-retail business acres/Town  \
# 0    0.000000                    0.18                        0.067815
# 1    0.000236                    0.00                        0.242302
# 2    0.000236                    0.00                        0.242302
# 3    0.000293                    0.00                        0.063050
# 4    0.000705                    0.00                        0.063050
#
#    Charles River  NO2 concentration  Average Rooms/Dwelling.  \
# 0            0.0           0.314815                 0.577505
# 1            0.0           0.172840                 0.547998
# 2            0.0           0.172840                 0.694386
# 3            0.0           0.150206                 0.658555
# 4            0.0           0.150206                 0.687105
#
#    Prior Built Units Proportion  Distance to Employment Centres  \
# 0                      0.641607                        0.269203
# 1                      0.782698                        0.348962
# 2                      0.599382                        0.348962
# 3                      0.441813                        0.448545
# 4                      0.528321                        0.448545
#
#    Radial Highways Distance  ValueProperty/tax rate  Teacher/town  \
# 0                  0.000000                0.208015      0.287234
# 1                  0.043478                0.104962      0.553191
# 2                  0.043478                0.104962      0.553191
# 3                  0.086957                0.066794      0.648936
# 4                  0.086957                0.066794      0.648936
#
#    blacks/town  Lower Status Percent
# 0     1.000000              0.089680
# 1     1.000000              0.204470
# 2     0.989737              0.063466
# 3     0.994276              0.033389
# 4     1.000000              0.099338

# %% [markdown]
# ### Train Test Splitting

# %% [markdown]
# **Task 6: Split the data into training and testing set and print their shapes.**

# %%
# Write code here
from sklearn.model_selection import train_test_split
xtrain ,xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.3, random_state=25, shuffle=True)

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_regression = Ridge(alpha=0.01)
ridge_regression
# Out:
# Ridge(alpha=0.01)

# %%
ridge_regression.fit(xtrain, ytrain)
pred = ridge_regression.predict(xtest)

# %%
pred
# Out:
# array([[23.19447788],
#        [19.48788348],
#        [25.13570446],
#        [ 6.2828263 ],
#        [18.18613417],
#        [25.60114481],
#        [34.51488423],
#        [12.45996357],
#        [14.03396224],
#        [34.11852049],
#        [14.07151273],
#        [13.84412486],
#        [18.89364008],
#        [19.67458208],
#        [35.98760858],
#        [23.25856148],
#        [28.73267031],
#        [ 3.81092271],
#        [ 7.98862613],
#        [24.29111233],
#        [23.20268642],
#        [14.17468737],
#        [29.92382769],
#        [27.34646537],
#        [23.51094984],
#        [23.19251301],
#        [38.98887622],
#        [23.2530682 ],
#        [23.89565101],
#        [23.27331038],
#        [30.89881504],
#        [31.77080042],
#        [17.46628292],
#        [13.05668749],
#        [14.30729952],
#        [20.78077166],
#        [17.83416744],
#        [27.43918391],
#        [25.15432409],
#        [21.22117991],
#        [18.21112732],
#        [21.88392035],
#        [17.24092195],
#        [17.95244894],
#        [14.65737007],
#        [25.42323507],
#        [23.61324753],
#        [28.5535314 ],
#        [30.34520821],
#        [10.46838791],
#        [18.41823095],
#        [19.45202832],
#        [34.07459881],
#        [19.01188829],
#        [20.16832559],
#        [15.33737642],
#        [34.55947595],
#        [27.69315956],
#        [14.53782226],
#        [32.34496816],
#        [22.7722807 ],
#        [20.4157289 ],
#        [27.3793407 ],
#        [20.46743612],
#        [24.71886025],
#        [14.13015479],
#        [22.73226913],
#        [29.94667572],
#        [26.15414508],
#        [15.10584635],
#        [20.6156197 ],
#        [23.09894419],
#        [15.71987202],
#        [23.17586261],
#        [38.13048531],
#        [26.24566389],
#        [18.48826833],
#        [30.11342007],
#        [27.06551295],
#        [25.38545689],
#        [27.52545779],
#        [22.20449827],
#        [30.58979792],
#        [18.51173192],
#        [ 7.6462703 ],
#        [22.65215364],
#        [23.25231325],
#        [23.27676406],
#        [26.38377996],
#        [23.25985096],
#        [14.8572032 ],
#        [20.38025228],
#        [17.02421844],
#        [16.30721492],
#        [31.85635252],
#        [23.30155057],
#        [20.70080308],
#        [28.43397265],
#        [10.35400224],
#        [31.57254844],
#        [13.13986713],
#        [24.91485042],
#        [20.41853466],
#        [18.77572847],
#        [10.89126194],
#        [18.84169794],
#        [16.96874467],
#        [28.61983471],
#        [37.52178562],
#        [19.79539212],
#        [17.94337177],
#        [26.59867555],
#        [18.64134645],
#        [14.37714856],
#        [28.09473744],
#        [35.35204242],
#        [22.94684937],
#        [35.87122272],
#        [19.92339858],
#        [24.2908726 ],
#        [20.55637472],
#        [20.23163665],
#        [27.54213666],
#        [15.28430416],
#        [28.33186097],
#        [27.50908261],
#        [17.22052888],
#        [20.67698566],
#        [24.32409862],
#        [36.2958377 ],
#        [ 3.07254953],
#        [29.9805578 ],
#        [19.22364962],
#        [13.40503372],
#        [17.50223652],
#        [39.42271431],
#        [18.39633041],
#        [17.05758226],
#        [24.60020163],
#        [22.40547427],
#        [34.17074387],
#        [32.17659565],
#        [19.52762445],
#        [22.44794087],
#        [19.38434053],
#        [19.98099888],
#        [15.74604546],
#        [25.10071271],
#        [33.41756133],
#        [29.20878048],
#        [24.73333658],
#        [19.56349394]])

# %%
from sklearn.metrics import r2_score
r2_score(ytest,pred)
# Out:
# 0.7134655069693907

# %%
# !pip install yellowbrick

# %%
from yellowbrick.regressor import ResidualsPlot
plt.figure(figsize=(15,6))
visualizer = ResidualsPlot(ridge_regression,hist=True)
visualizer.fit(xtrain.values, ytrain.values)  
visualizer.score(xtest.values, ytest.values)  
visualizer.poof()

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_regression = Lasso(alpha=0.001) 
lasso_regression
# Out:
# Lasso(alpha=0.001)

# %%
lasso_regression.fit(xtrain, ytrain)
pred = lasso_regression.predict(xtest)
r2_score(ytest,pred)
# Out:
# 0.7136059326484789

# %% [markdown]
# ### Alpha Selection Visualizer

# %% [markdown]
# The <mark>AlphaSelection</mark> Visualizer demonstrates how different values of alpha influence model selection during the regularization of linear models. Since regularization is designed to penalize model complexity, the higher the alpha, the less complex the model, decreasing the error due to variance (overfit). However, alphas that are too high increase the error due to bias (underfit). Therefore, it is important to choose an optimal alpha such that the error is minimized in both directions.
#
# To do this, typically you would you use one of the <mark>"RegressionCV”</mark> models in scikit-learn. E.g. instead of using the Ridge (L2) regularizer, use RidgeCV and pass a list of alphas, which will be selected based on the cross-validation score of each alpha. This visualizer wraps a “RegressionCV” model and visualizes the alpha/error curve. If the visualization shows a jagged or random plot, then potentially the model is not sensitive to that type of regularization and another is required (e.g. L1 or Lasso regularization).

# %%
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection

# %%
alphas = np.logspace(-10, 1, 40)
alphas
# Out:
# array([1.00000000e-10, 1.91448198e-10, 3.66524124e-10, 7.01703829e-10,
#        1.34339933e-09, 2.57191381e-09, 4.92388263e-09, 9.42668455e-09,
#        1.80472177e-08, 3.45510729e-08, 6.61474064e-08, 1.26638017e-07,
#        2.42446202e-07, 4.64158883e-07, 8.88623816e-07, 1.70125428e-06,
#        3.25702066e-06, 6.23550734e-06, 1.19377664e-05, 2.28546386e-05,
#        4.37547938e-05, 8.37677640e-05, 1.60371874e-04, 3.07029063e-04,
#        5.87801607e-04, 1.12533558e-03, 2.15443469e-03, 4.12462638e-03,
#        7.89652287e-03, 1.51177507e-02, 2.89426612e-02, 5.54102033e-02,
#        1.06081836e-01, 2.03091762e-01, 3.88815518e-01, 7.44380301e-01,
#        1.42510267e+00, 2.72833338e+00, 5.22334507e+00, 1.00000000e+01])

# %%
# Create a list of alphas to cross-validate against 
alphas = np.logspace(-20, 1, 100)

# Instantiate the linear model and visualizer 
model = LassoCV(alphas=alphas, cv=5)
visualizer = AlphaSelection(model)

visualizer.fit(xtrain, ytrain)        
g = visualizer.poof()
# Out:
# F:\Anaconda3_1\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 451.18433279556484, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 580.4302254529521, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1670.580106356172, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1383.6298660814464, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2199.5686133150293, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2582.919274256981, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2833.376003070009, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2992.7903053670407, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3013.2542965834004, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3217.221170034637, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231.751957063516, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3217.071565617241, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3249.0770099541655, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3244.1910301979715, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3251.1386972235496, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3250.8617692466564, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3252.4192156451304, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3253.678619097081, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3253.961586342609, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3254.3215150061988, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3254.7528056065967, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3254.7496278649096, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3254.717034713008, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3254.7850663607387, tolerance: 2.334563901060071
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 415.5458857455469, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1133.3143423717074, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1249.1688400196053, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 956.9324932905447, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2153.056496509954, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2757.3314367981984, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2704.1040615908187, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2756.3938015948725, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2848.4717685774067, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2860.220095994956, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2912.9966467700915, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2945.6186935319033, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2981.7377678098137, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2984.6547512591565, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2989.728243404809, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2994.822941386975, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2993.237364632245, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2994.99746539421, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2996.9355123671, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2995.687986817143, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2997.5780956727376, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2997.680184074798, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2997.6312888810685, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2997.7188210728245, tolerance: 2.3760891519434626
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 656.763073228778, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 890.1126961813911, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 855.7981797201228, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1551.1880654315123, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2809.5101746047612, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2750.39189279329, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2941.303811881492, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2952.0112705325914, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3025.6810582473604, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3006.185052769648, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3019.041049270381, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3050.3713501426632, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3064.02023291886, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3056.9895597775035, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3068.9297238865015, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3074.1593865176314, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3074.0903360535603, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3076.060401959955, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3076.705332224864, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3076.127870028209, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3076.7664823925393, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3077.0458172638296, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3077.0837429084713, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3077.1473015073325, tolerance: 2.6125305017667846
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1713.6039448939168, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1212.3682132595027, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 271.6385270822557, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2187.9692961101314, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2408.0397811630837, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3058.595019721177, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3025.391559973204, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3012.208400477375, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3047.165732821607, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3147.620587511749, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3146.284168426937, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3169.639385387284, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3189.7276464381084, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3196.359003304482, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3202.5879345594903, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3205.1376916533563, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3204.9532804776804, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3206.048563089909, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3205.9855033500694, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3206.152417940183, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3206.672909787061, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3206.733655615935, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3206.643081860929, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3206.823451428899, tolerance: 2.685373978798587
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 688.253426260666, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167.53376041096817, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1349.617485364428, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1986.9512751895668, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2696.752328470167, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2904.9503634908583, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2828.950762035696, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3053.3728142333443, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3088.937452547388, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3201.1553013101, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3214.381950337215, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3228.6837804591023, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3233.9835897251382, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3230.0199944614947, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3246.1907568763013, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3243.37922140799, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3250.356969521348, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3250.2418262019387, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3249.591811618394, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3250.6953251784835, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3251.1077181761843, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3251.2435741399204, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3251.2828113783526, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:528: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3251.2968629225306, tolerance: 2.4901610246478874
#   tol, rng, random, positive)
# F:\Anaconda3_1\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3759.3757591739154, tolerance: 3.126028759887006
#   positive)
